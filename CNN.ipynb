# %%
import numpy as np
import pandas as pd

# Sklearn
#from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

# Torch
import torch
import torch.nn as nn
#import torch.nn.functional as F 
from torch.utils.data import DataLoader, TensorDataset
#from torch.autograd import Variable
#from torchvision import datasets
#from torchvision.transforms import ToTensor
#from torch import tensor
#import torch.optim as optim
from torchinfo import summary

# Plotting
import matplotlib.pyplot as plt
#from matplotlib.lines import Line2D
#import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Links

# %% [markdown]
# https://github.com/Bjarten/early-stopping-pytorch/blob/master/pytorchtools.py
#
# https://medium.com/@deepeshdeepakdd2/lenet-5-implementation-on-mnist-in-pytorch-c6f2ee306e37
#
# https://deepnote.com/workspace/ludekcizinsky-8f7f55a7-f3c7-4009-b3b2-b7b07fcdf5a7/project/ml202220-44b4318f-b707-4245-8a54-52edfdffa4de/notebook/dd926b1b8ea94ce79538cc9365bc74b7

# %% [markdown]
# ### Load Data

# %%
# Load the data
data_train = np.load('data/fashion_train.npy', mmap_mode='r')
data_test = np.load('data/fashion_test.npy', mmap_mode='r')

# Scaling
X_train = data_train[:, :-1]/255
y_train = data_train[:, -1]

X_test = data_test[:, :-1]/255
y_test = data_test[:, -1]

# %%
# Convert to PyTorch tensors
X_train_tensor = torch.Tensor(X_train)
y_train_tensor = torch.Tensor(y_train).long()
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long) 

# Reshape X_train and X_test for convolutional input (assuming 28x28 images)
X_train_tensor = X_train_tensor.view(-1, 1, 28, 28)  # Adjust dimensions based on your actual image size
X_test_tensor = X_test_tensor.view(-1, 1, 28, 28)  # Adjust dimensions based on your actual image size

# Create TensorDataset
data_train_tensor = TensorDataset(X_train_tensor, y_train_tensor)
data_test_tensor = TensorDataset(X_test_tensor, y_test_tensor)

# Split training into training and validation
g_cpu = torch.Generator()
g_cpu.manual_seed(3)
data_train_tensor, data_val_tensor = torch.utils.data.random_split(data_train_tensor, [8000, 2000])

# %% [markdown]
# ### LeNet modified

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Implementation is taken https://github.com/Bjarten/early-stopping-pytorch/blob/master/pytorchtools.py

class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
class CNN(nn.Module):
    def __init__(self, activation_fn, drop_out_rate, batch_size, epochs, train_data, val_data, test_data, loss_fn, lr, optimizer, verbose, patience=7, delta=0):

        # Inherit from nn module
        super(CNN, self).__init__()

        # Define activation function
        self.activation_fn = activation_fn

        # Define drop ratio
        self.drop_out_rate = drop_out_rate
        
        # Define neural network architecture
        self.nn = nn.Sequential(

                # C1 6@28x28
                nn.Conv2d(1, 6, kernel_size=5, stride=1, padding=2),
                nn.BatchNorm2d(6),
                self.activation_fn(),
                nn.AvgPool2d(kernel_size=2, stride=2),
                
                # C3: 16@10x10
                #nn.Dropout(self.drop_out_rate),
                nn.Conv2d(6, 16, kernel_size=5, stride=1, padding=0),
                nn.BatchNorm2d(16),
                self.activation_fn(),
                nn.AvgPool2d(kernel_size=2, stride=2),
                
                # Apply flattening on the output
                nn.Flatten(),
                
                # Dense part
                # L1
                nn.Dropout(self.drop_out_rate),
                nn.Linear(16 * 5 * 5, 120),
                nn.BatchNorm1d(120),
                self.activation_fn(),
                
                # L2
                nn.Dropout(self.drop_out_rate),
                nn.Linear(120, 84),
                nn.BatchNorm1d(84),
                self.activation_fn(),
                
                # L3
                nn.Dropout(self.drop_out_rate),
                nn.Linear(84, 10))

        # Define batch size
        self.batch_size = batch_size

        # Define numper of epochs
        self.epochs = epochs

        # Define datasets
        self.training_data = DataLoader(
            train_data, batch_size=self.batch_size, shuffle=True, num_workers=1)
        self.validation_data = DataLoader(
            val_data, batch_size=self.batch_size, shuffle=True, num_workers=1)
        self.test_data = DataLoader(
            test_data, batch_size=len(test_data), shuffle=True, num_workers=1)

        # Define loss function
        self.loss_fn = loss_fn

        # Define learning rate
        self.lr = lr

        # Define optimizer
        self.optimizer = optimizer(self.parameters(), lr=self.lr)

        # Print status if true
        self.verbose = verbose

        # Define patience and delta for early stopping
        self.patience = patience
        self.delta = delta

        # Save training progress
        self.train_loss_history = []
        self.train_acc_history = []

        self.val_loss_history = []
        self.val_acc_history = []
    
    def forward(self, x):
        logits = self.nn(x)
        return logits
    
    def train_loop(self):
        size = len(self.training_data.dataset)
        num_batches = len(self.validation_data)
        train_loss, correct = 0, 0

        for batch, (X, y) in enumerate(self.training_data):
            self.train() # Specify that model is training to enable batchnorm and dropout

            # Compute prediction and loss
            pred = self.forward(X)
            loss = self.loss_fn(pred, y)

            # Backpropagation
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

            # Calculate train loss and accuracy
            train_loss += loss.item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

            if self.verbose:
                if batch % 20 == 0:
                    loss, current = loss.item(), batch * len(X)
                    print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

        train_loss /= num_batches
        correct /= size

        # Save it to history
        self.train_acc_history.append(correct)
        self.train_loss_history.append(train_loss)

    def val_loop(self):
        self.eval() # Specify that model is not training to disable batchnorm and dropout
        
        size = len(self.validation_data.dataset)
        num_batches = len(self.validation_data)
        val_loss, correct = 0, 0

        with torch.no_grad():
            for X, y in self.validation_data:

                pred = self.forward(X)

                # Calculate validation loss and accuracy
                val_loss += self.loss_fn(pred, y).item()
                correct += (pred.argmax(1) == y).type(torch.float).sum().item()
        
        val_loss /= num_batches
        correct /= size

        if self.verbose:
            print(
                f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {val_loss:>8f} \n")

        # Save it to history
        self.val_acc_history.append(correct)
        self.val_loss_history.append(val_loss)

    def fit(self):

        early_stopping = EarlyStopping(patience=self.patience, verbose=self.verbose, delta=self.delta)
        
        for t in range(self.epochs):
            if self.verbose:
                print(f"Epoch {t+1}\n-------------------------------")
            
            self.train_loop()
            self.val_loop()

            # Early stopping
            early_stopping(self.val_loss_history[-1], self)

            if early_stopping.early_stop:
                print('Early stopping.')
                break

        print("Done!")

    def predict(self, x):
        logits = self.forward(x)
        softmax = nn.Softmax(dim=1)
        
        return  softmax(logits).argmax(1) #torch.max(logits,1)[1] 

    def test(self):
        # Get data
        X, y = next(iter(self.test_data))

        # Predict values
        y_hat = self.predict(X)

        print("Accuracy score for test data")
        print("-"*60)
        print(f"Acc: {accuracy_score(y, y_hat)*100} %")
        print()
        print("Confusion matrix for test data")
        print("-"*60)
        print(confusion_matrix(y, y_hat))

# %% [markdown]
# #### Parameters
# **Loss function**<br>
# We choose to use cross entropy since we want a categorical output.
#
# **Optimizer**
# The optimizer algorithm changes the weights depending on the loss function gradient. We take Adam since it's better than SGD.
#
# **Activation function**
# Sigmoid and Softmax.
#
# **Drop out rate**
#
# **Batch_size**
#
# **Epochs**
# We use early stopping.
#
# **Learning rate**

# %% [markdown]
# ### Cross validation

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, roc_auc_score, make_scorer
from sklearn.model_selection import StratifiedKFold

# %%
history = {'lr': [], 'dpr': [], 'batch_size':[], 'train_loss': [], 'val_loss': [], 'train_acc':[], 'val_acc': []}

num_folds = 5
learning_rates = [0.001, 0.0001]
drop_out_rates = [0.1, 0.3, 0.5]
batch_size = [16, 32, 64]

for lr in learning_rates:
    for dpr in drop_out_rates:
        for b in batch_size:
            print(f'Training model with learning rate: {lr}, drop out rate {dpr} and batch size {b}.')

            train_loss, val_loss, train_acc, val_acc = 0,0,0,0

            skf = StratifiedKFold(num_folds, random_state=0, shuffle=True)
            for i, (train_idx, val_idx) in enumerate(skf.split(X_train,y_train)):

            #for fold in range(num_folds):
                
                print(f'Fold {i}------------------------------')
                #data_train, data_val = torch.utils.data.random_split(data_training, [8000, 2000])
                
                # Convert to PyTorch tensors
                X_train_tensor = torch.Tensor(X_train[train_idx])
                y_train_tensor = torch.Tensor(y_train[train_idx]).long()
                X_val_tensor = torch.tensor(X_train[val_idx], dtype=torch.float32)
                y_val_tensor = torch.tensor(y_train[val_idx], dtype=torch.long) 

                # Reshape X_train and X_test for convolutional input (assuming 28x28 images)
                X_train_tensor = X_train_tensor.view(-1, 1, 28, 28)  # Adjust dimensions based on your actual image size
                X_val_tensor = X_test_tensor.view(-1, 1, 28, 28)  # Adjust dimensions based on your actual image size

                # Create TensorDataset
                data_train_tensor = TensorDataset(X_train_tensor, y_train_tensor)
                data_val_tensor = TensorDataset(X_test_tensor, y_test_tensor)

                model = CNN(activation_fn=nn.Sigmoid,
                    drop_out_rate=dpr,
                    batch_size=b, 
                    epochs=250, 
                    train_data=data_train_tensor, 
                    val_data=data_val_tensor, 
                    test_data=data_test_tensor, 
                    loss_fn=nn.CrossEntropyLoss(), 
                    lr=lr, 
                    optimizer=torch.optim.Adam, 
                    verbose=False, 
                    patience=10, 
                    delta=0)
            
                model.fit()

                min_idx = np.argmin(model.val_loss_history)

                train_loss += model.train_loss_history[min_idx]
                val_loss += model.val_loss_history[min_idx]
                train_acc += model.train_acc_history[min_idx]
                val_acc += model.val_acc_history[min_idx]

            train_loss /= num_folds
            val_loss /= num_folds
            train_acc /= num_folds
            val_acc /= num_folds

            print(f'Average result of validation\nLoss\nTraining: {train_loss}, validation: {val_loss}\nAccuracy:\nTraining: {train_acc}, validation: {val_acc}')

            history['lr'].append(lr)
            history['dpr'].append(dpr)
            history['batch_size'].append(b)
            history['train_loss'].append(train_loss)
            history['val_loss'].append(val_loss)
            history['train_acc'].append(train_acc)
            history['val_acc'].append(val_acc)
# Out:
# Training model with learning rate: 0.001, drop out rate 0.1 and batch size 16.
# Fold 0------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 1------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 2------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 3------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 4------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Average result of validation
# Loss
# Training: 0.4181009836170596, validation: 0.32732791282034246
# Accuracy:
# Training: 0.9002249999999998, validation: 0.881
# Training model with learning rate: 0.001, drop out rate 0.1 and batch size 32.
# Fold 0------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 1------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 2------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 3------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 4------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Average result of validation
# Loss
# Training: 0.4264996646648379, validation: 0.33100144402806164
# Accuracy:
# Training: 0.8987, validation: 0.88016
# Training model with learning rate: 0.001, drop out rate 0.1 and batch size 64.
# Fold 0------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 1------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 2------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 3------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 4------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Average result of validation
# Loss
# Training: 0.4032496022084091, validation: 0.34145820501107205
# Accuracy:
# Training: 0.9023749999999999, validation: 0.8775599999999999
# Training model with learning rate: 0.001, drop out rate 0.3 and batch size 16.
# Fold 0------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 1------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 2------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 3------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 4------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Average result of validation
# Loss
# Training: 0.5176735511674477, validation: 0.31703115982797964
# Accuracy:
# Training: 0.8773, validation: 0.8813599999999999
# Training model with learning rate: 0.001, drop out rate 0.3 and batch size 32.
# Fold 0------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 1------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 2------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 3------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 4------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Average result of validation
# Loss
# Training: 0.4858076524962285, validation: 0.3194540681542864
# Accuracy:
# Training: 0.8830500000000001, validation: 0.88168
# Training model with learning rate: 0.001, drop out rate 0.3 and batch size 64.
# Fold 0------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 1------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 2------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 3------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 4------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Average result of validation
# Loss
# Training: 0.4381125851522518, validation: 0.32001810439779793
# Accuracy:
# Training: 0.8935500000000001, validation: 0.88372
# Training model with learning rate: 0.001, drop out rate 0.5 and batch size 16.
# Fold 0------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 1------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 2------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# ...
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Done!
# Fold 1------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 2------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Fold 3------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# Done!
# Fold 4------------------------------
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!
# Average result of validation
# Loss
# Training: 0.8433650559262384, validation: 0.43791398966236966
# Accuracy:
# Training: 0.795825, validation: 0.8244

# %%
history_df = pd.DataFrame(history)
history_df.to_csv('training_history.csv')

# %%
idx_max_acc=np.argmax(history_df['val_acc'])
history_df.iloc[idx_max_acc]
# Out:
# lr             0.001000
# dpr            0.300000
# batch_size    64.000000
# train_loss     0.438113
# val_loss       0.320018
# train_acc      0.893550
# val_acc        0.883720
# Name: 5, dtype: float64

# %% [markdown]
# ### Train final model

# %%
# Convert to PyTorch tensors
X_train_tensor = torch.Tensor(X_train)
y_train_tensor = torch.Tensor(y_train).long()
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long) 

# Reshape X_train and X_test for convolutional input (assuming 28x28 images)
X_train_tensor = X_train_tensor.view(-1, 1, 28, 28)  # Adjust dimensions based on your actual image size
X_test_tensor = X_test_tensor.view(-1, 1, 28, 28)  # Adjust dimensions based on your actual image size

# Create TensorDataset
data_train_tensor = TensorDataset(X_train_tensor, y_train_tensor)
data_test_tensor = TensorDataset(X_test_tensor, y_test_tensor)

# Split training into training and validation
g_cpu = torch.Generator()
g_cpu.manual_seed(3)
data_train_tensor, data_val_tensor = torch.utils.data.random_split(data_train_tensor, [8000, 2000])

# %%
# Initialize model
model = CNN(activation_fn=nn.Sigmoid,
         drop_out_rate=0.3,
         batch_size=64, 
         epochs=100, 
         train_data=data_train_tensor, 
         val_data=data_val_tensor, 
         test_data=data_test_tensor, 
         loss_fn=nn.CrossEntropyLoss(), 
         lr=0.001, 
         optimizer=torch.optim.Adam, 
         verbose=True, 
         patience=10, 
         delta=0)

# %%
model.fit()
# Out:
# Epoch 1
# -------------------------------
# loss: 2.409114  [    0/ 8000]
# loss: 1.627972  [ 1280/ 8000]
# loss: 1.307490  [ 2560/ 8000]
# loss: 1.148062  [ 3840/ 8000]
# loss: 1.147144  [ 5120/ 8000]
# loss: 0.995147  [ 6400/ 8000]
# loss: 0.909637  [ 7680/ 8000]
# Test Error:
#  Accuracy: 71.8%, Avg loss: 0.862710
#
# Validation loss decreased (inf --> 0.862710).  Saving model ...
# Epoch 2
# -------------------------------
# loss: 0.926272  [    0/ 8000]
# loss: 0.869681  [ 1280/ 8000]
# loss: 0.839564  [ 2560/ 8000]
# loss: 0.793552  [ 3840/ 8000]
# loss: 0.990237  [ 5120/ 8000]
# loss: 0.846417  [ 6400/ 8000]
# loss: 0.713920  [ 7680/ 8000]
# Test Error:
#  Accuracy: 73.0%, Avg loss: 0.679485
#
# Validation loss decreased (0.862710 --> 0.679485).  Saving model ...
# Epoch 3
# -------------------------------
# loss: 0.831724  [    0/ 8000]
# loss: 0.847582  [ 1280/ 8000]
# loss: 0.770154  [ 2560/ 8000]
# loss: 0.682906  [ 3840/ 8000]
# loss: 0.831430  [ 5120/ 8000]
# loss: 0.638636  [ 6400/ 8000]
# loss: 0.773108  [ 7680/ 8000]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.618578
#
# Validation loss decreased (0.679485 --> 0.618578).  Saving model ...
# Epoch 4
# -------------------------------
# loss: 0.608271  [    0/ 8000]
# loss: 0.756547  [ 1280/ 8000]
# loss: 0.689658  [ 2560/ 8000]
# loss: 0.692063  [ 3840/ 8000]
# loss: 0.623292  [ 5120/ 8000]
# loss: 0.800422  [ 6400/ 8000]
# loss: 0.564113  [ 7680/ 8000]
# Test Error:
#  Accuracy: 76.7%, Avg loss: 0.587298
#
# Validation loss decreased (0.618578 --> 0.587298).  Saving model ...
# Epoch 5
# -------------------------------
# loss: 0.621664  [    0/ 8000]
# loss: 0.567189  [ 1280/ 8000]
# loss: 0.710300  [ 2560/ 8000]
# loss: 0.565060  [ 3840/ 8000]
# loss: 0.523019  [ 5120/ 8000]
# loss: 0.662100  [ 6400/ 8000]
# loss: 0.720813  [ 7680/ 8000]
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.566937
#
# Validation loss decreased (0.587298 --> 0.566937).  Saving model ...
# Epoch 6
# -------------------------------
# loss: 0.653068  [    0/ 8000]
# loss: 0.630555  [ 1280/ 8000]
# loss: 0.537592  [ 2560/ 8000]
# loss: 0.633037  [ 3840/ 8000]
# loss: 0.542512  [ 5120/ 8000]
# loss: 0.492113  [ 6400/ 8000]
# loss: 0.849796  [ 7680/ 8000]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.541719
#
# Validation loss decreased (0.566937 --> 0.541719).  Saving model ...
# Epoch 7
# -------------------------------
# loss: 0.502499  [    0/ 8000]
# loss: 0.422337  [ 1280/ 8000]
# loss: 0.466839  [ 2560/ 8000]
# loss: 0.538183  [ 3840/ 8000]
# loss: 0.711139  [ 5120/ 8000]
# loss: 0.749317  [ 6400/ 8000]
# loss: 0.516345  [ 7680/ 8000]
# Test Error:
#  Accuracy: 77.6%, Avg loss: 0.567916
#
# EarlyStopping counter: 1 out of 10
# Epoch 8
# -------------------------------
# loss: 0.602683  [    0/ 8000]
# loss: 0.639600  [ 1280/ 8000]
# loss: 0.665416  [ 2560/ 8000]
# loss: 0.515659  [ 3840/ 8000]
# loss: 0.722837  [ 5120/ 8000]
# loss: 0.396575  [ 6400/ 8000]
# loss: 0.466409  [ 7680/ 8000]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.524800
#
# Validation loss decreased (0.541719 --> 0.524800).  Saving model ...
# Epoch 9
# -------------------------------
# loss: 0.405834  [    0/ 8000]
# loss: 0.667946  [ 1280/ 8000]
# loss: 0.490491  [ 2560/ 8000]
# loss: 0.727477  [ 3840/ 8000]
# loss: 0.477700  [ 5120/ 8000]
# loss: 0.473015  [ 6400/ 8000]
# loss: 0.522200  [ 7680/ 8000]
# Test Error:
#  Accuracy: 81.5%, Avg loss: 0.480599
#
# Validation loss decreased (0.524800 --> 0.480599).  Saving model ...
# Epoch 10
# -------------------------------
# loss: 0.425832  [    0/ 8000]
# loss: 0.533515  [ 1280/ 8000]
# loss: 0.420539  [ 2560/ 8000]
# loss: 0.534985  [ 3840/ 8000]
# loss: 0.493584  [ 5120/ 8000]
# loss: 0.548314  [ 6400/ 8000]
# loss: 0.406723  [ 7680/ 8000]
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.573564
#
# EarlyStopping counter: 1 out of 10
# Epoch 11
# -------------------------------
# loss: 0.560328  [    0/ 8000]
# loss: 0.521842  [ 1280/ 8000]
# loss: 0.471787  [ 2560/ 8000]
# loss: 0.548442  [ 3840/ 8000]
# loss: 0.485323  [ 5120/ 8000]
# loss: 0.693001  [ 6400/ 8000]
# loss: 0.538366  [ 7680/ 8000]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.459646
#
# Validation loss decreased (0.480599 --> 0.459646).  Saving model ...
# Epoch 12
# -------------------------------
# loss: 0.388917  [    0/ 8000]
# loss: 0.423628  [ 1280/ 8000]
# loss: 0.607556  [ 2560/ 8000]
# loss: 0.419946  [ 3840/ 8000]
# loss: 0.568930  [ 5120/ 8000]
# loss: 0.550019  [ 6400/ 8000]
# loss: 0.473739  [ 7680/ 8000]
# Test Error:
#  Accuracy: 83.4%, Avg loss: 0.442300
#
# Validation loss decreased (0.459646 --> 0.442300).  Saving model ...
# Epoch 13
# -------------------------------
# loss: 0.671252  [    0/ 8000]
# loss: 0.593652  [ 1280/ 8000]
# loss: 0.504068  [ 2560/ 8000]
# loss: 0.494711  [ 3840/ 8000]
# loss: 0.395478  [ 5120/ 8000]
# loss: 0.437727  [ 6400/ 8000]
# loss: 0.350854  [ 7680/ 8000]
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.443193
#
# EarlyStopping counter: 1 out of 10
# Epoch 14
# -------------------------------
# loss: 0.439208  [    0/ 8000]
# loss: 0.640753  [ 1280/ 8000]
# loss: 0.354749  [ 2560/ 8000]
# loss: 0.603632  [ 3840/ 8000]
# loss: 0.416738  [ 5120/ 8000]
# loss: 0.468296  [ 6400/ 8000]
# loss: 0.414431  [ 7680/ 8000]
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.443364
#
# EarlyStopping counter: 2 out of 10
# Epoch 15
# -------------------------------
# loss: 0.337732  [    0/ 8000]
# loss: 0.413080  [ 1280/ 8000]
# loss: 0.423502  [ 2560/ 8000]
# loss: 0.436734  [ 3840/ 8000]
# loss: 0.716015  [ 5120/ 8000]
# loss: 0.505632  [ 6400/ 8000]
# loss: 0.795760  [ 7680/ 8000]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.448221
#
# EarlyStopping counter: 3 out of 10
# Epoch 16
# -------------------------------
# loss: 0.452579  [    0/ 8000]
# loss: 0.456410  [ 1280/ 8000]
# loss: 0.760701  [ 2560/ 8000]
# loss: 0.543731  [ 3840/ 8000]
# loss: 0.430199  [ 5120/ 8000]
# loss: 0.494961  [ 6400/ 8000]
# loss: 0.576926  [ 7680/ 8000]
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.421278
#
# Validation loss decreased (0.442300 --> 0.421278).  Saving model ...
# Epoch 17
# -------------------------------
# loss: 0.337639  [    0/ 8000]
# loss: 0.325164  [ 1280/ 8000]
# loss: 0.447578  [ 2560/ 8000]
# loss: 0.251632  [ 3840/ 8000]
# loss: 0.440862  [ 5120/ 8000]
# loss: 0.472096  [ 6400/ 8000]
# loss: 0.561520  [ 7680/ 8000]
# Test Error:
#  Accuracy: 84.7%, Avg loss: 0.416076
#
# Validation loss decreased (0.421278 --> 0.416076).  Saving model ...
# Epoch 18
# -------------------------------
# loss: 0.377364  [    0/ 8000]
# loss: 0.400342  [ 1280/ 8000]
# loss: 0.461385  [ 2560/ 8000]
# loss: 0.401441  [ 3840/ 8000]
# loss: 0.500801  [ 5120/ 8000]
# loss: 0.443709  [ 6400/ 8000]
# loss: 0.370282  [ 7680/ 8000]
# Test Error:
#  Accuracy: 85.3%, Avg loss: 0.405233
#
# Validation loss decreased (0.416076 --> 0.405233).  Saving model ...
# Epoch 19
# -------------------------------
# loss: 0.457369  [    0/ 8000]
# loss: 0.761451  [ 1280/ 8000]
# loss: 0.434179  [ 2560/ 8000]
# loss: 0.465911  [ 3840/ 8000]
# loss: 0.291413  [ 5120/ 8000]
# loss: 0.398390  [ 6400/ 8000]
# loss: 0.284044  [ 7680/ 8000]
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.415942
#
# EarlyStopping counter: 1 out of 10
# Epoch 20
# -------------------------------
# loss: 0.317147  [    0/ 8000]
# loss: 0.394981  [ 1280/ 8000]
# loss: 0.427342  [ 2560/ 8000]
# loss: 0.449264  [ 3840/ 8000]
# loss: 0.312487  [ 5120/ 8000]
# loss: 0.586933  [ 6400/ 8000]
# loss: 0.439344  [ 7680/ 8000]
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.413532
#
# EarlyStopping counter: 2 out of 10
# Epoch 21
# -------------------------------
# loss: 0.503164  [    0/ 8000]
# loss: 0.344273  [ 1280/ 8000]
# loss: 0.338198  [ 2560/ 8000]
# loss: 0.625267  [ 3840/ 8000]
# loss: 0.389078  [ 5120/ 8000]
# loss: 0.391005  [ 6400/ 8000]
# loss: 0.433499  [ 7680/ 8000]
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.385866
#
# Validation loss decreased (0.405233 --> 0.385866).  Saving model ...
# Epoch 22
# -------------------------------
# loss: 0.422867  [    0/ 8000]
# loss: 0.555743  [ 1280/ 8000]
# loss: 0.404170  [ 2560/ 8000]
# loss: 0.512117  [ 3840/ 8000]
# loss: 0.375693  [ 5120/ 8000]
# loss: 0.640203  [ 6400/ 8000]
# loss: 0.430396  [ 7680/ 8000]
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.380525
#
# Validation loss decreased (0.385866 --> 0.380525).  Saving model ...
# Epoch 23
# -------------------------------
# loss: 0.232022  [    0/ 8000]
# loss: 0.341580  [ 1280/ 8000]
# loss: 0.436221  [ 2560/ 8000]
# loss: 0.509144  [ 3840/ 8000]
# loss: 0.329884  [ 5120/ 8000]
# loss: 0.457215  [ 6400/ 8000]
# loss: 0.540730  [ 7680/ 8000]
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.427291
#
# EarlyStopping counter: 1 out of 10
# Epoch 24
# -------------------------------
# loss: 0.404125  [    0/ 8000]
# loss: 0.311660  [ 1280/ 8000]
# loss: 0.397043  [ 2560/ 8000]
# loss: 0.482384  [ 3840/ 8000]
# loss: 0.265922  [ 5120/ 8000]
# loss: 0.373363  [ 6400/ 8000]
# loss: 0.506023  [ 7680/ 8000]
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.434673
#
# EarlyStopping counter: 2 out of 10
# Epoch 25
# -------------------------------
# loss: 0.317576  [    0/ 8000]
# loss: 0.422885  [ 1280/ 8000]
# loss: 0.470111  [ 2560/ 8000]
# loss: 0.188064  [ 3840/ 8000]
# loss: 0.409069  [ 5120/ 8000]
# loss: 0.403925  [ 6400/ 8000]
# loss: 0.312921  [ 7680/ 8000]
# Test Error:
#  Accuracy: 85.6%, Avg loss: 0.383110
#
# EarlyStopping counter: 3 out of 10
# Epoch 26
# -------------------------------
# loss: 0.480231  [    0/ 8000]
# loss: 0.368037  [ 1280/ 8000]
# loss: 0.365833  [ 2560/ 8000]
# loss: 0.476660  [ 3840/ 8000]
# loss: 0.366719  [ 5120/ 8000]
# loss: 0.378031  [ 6400/ 8000]
# loss: 0.510952  [ 7680/ 8000]
# Test Error:
#  Accuracy: 85.3%, Avg loss: 0.411129
#
# EarlyStopping counter: 4 out of 10
# Epoch 27
# -------------------------------
# loss: 0.457289  [    0/ 8000]
# loss: 0.349008  [ 1280/ 8000]
# loss: 0.463394  [ 2560/ 8000]
# loss: 0.426166  [ 3840/ 8000]
# loss: 0.392906  [ 5120/ 8000]
# loss: 0.423740  [ 6400/ 8000]
# loss: 0.335917  [ 7680/ 8000]
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.375219
#
# Validation loss decreased (0.380525 --> 0.375219).  Saving model ...
# Epoch 28
# -------------------------------
# loss: 0.328031  [    0/ 8000]
# loss: 0.290616  [ 1280/ 8000]
# loss: 0.403004  [ 2560/ 8000]
# loss: 0.422427  [ 3840/ 8000]
# loss: 0.430973  [ 5120/ 8000]
# loss: 0.533503  [ 6400/ 8000]
# loss: 0.290183  [ 7680/ 8000]
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.412448
#
# EarlyStopping counter: 1 out of 10
# Epoch 29
# -------------------------------
# loss: 0.379471  [    0/ 8000]
# loss: 0.294154  [ 1280/ 8000]
# loss: 0.468931  [ 2560/ 8000]
# loss: 0.416286  [ 3840/ 8000]
# loss: 0.351460  [ 5120/ 8000]
# loss: 0.336861  [ 6400/ 8000]
# loss: 0.393190  [ 7680/ 8000]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.372827
#
# Validation loss decreased (0.375219 --> 0.372827).  Saving model ...
# Epoch 30
# -------------------------------
# loss: 0.366355  [    0/ 8000]
# loss: 0.389290  [ 1280/ 8000]
# loss: 0.420821  [ 2560/ 8000]
# loss: 0.484360  [ 3840/ 8000]
# loss: 0.292556  [ 5120/ 8000]
# loss: 0.345030  [ 6400/ 8000]
# loss: 0.233912  [ 7680/ 8000]
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.406956
#
# EarlyStopping counter: 1 out of 10
# Epoch 31
# -------------------------------
# loss: 0.439744  [    0/ 8000]
# loss: 0.444640  [ 1280/ 8000]
# loss: 0.433391  [ 2560/ 8000]
# loss: 0.302372  [ 3840/ 8000]
# loss: 0.632887  [ 5120/ 8000]
# loss: 0.223959  [ 6400/ 8000]
# loss: 0.512694  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.366106
#
# Validation loss decreased (0.372827 --> 0.366106).  Saving model ...
# Epoch 32
# -------------------------------
# loss: 0.226469  [    0/ 8000]
# loss: 0.232919  [ 1280/ 8000]
# loss: 0.248209  [ 2560/ 8000]
# loss: 0.340329  [ 3840/ 8000]
# loss: 0.230934  [ 5120/ 8000]
# loss: 0.419768  [ 6400/ 8000]
# loss: 0.468131  [ 7680/ 8000]
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.372132
#
# EarlyStopping counter: 1 out of 10
# Epoch 33
# -------------------------------
# loss: 0.368615  [    0/ 8000]
# loss: 0.312752  [ 1280/ 8000]
# loss: 0.483559  [ 2560/ 8000]
# loss: 0.258516  [ 3840/ 8000]
# loss: 0.584624  [ 5120/ 8000]
# loss: 0.373152  [ 6400/ 8000]
# loss: 0.454714  [ 7680/ 8000]
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.363381
#
# Validation loss decreased (0.366106 --> 0.363381).  Saving model ...
# Epoch 34
# -------------------------------
# loss: 0.224982  [    0/ 8000]
# loss: 0.407319  [ 1280/ 8000]
# loss: 0.369582  [ 2560/ 8000]
# loss: 0.452484  [ 3840/ 8000]
# loss: 0.426225  [ 5120/ 8000]
# loss: 0.226928  [ 6400/ 8000]
# loss: 0.467708  [ 7680/ 8000]
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.354213
#
# Validation loss decreased (0.363381 --> 0.354213).  Saving model ...
# Epoch 35
# -------------------------------
# loss: 0.423535  [    0/ 8000]
# loss: 0.419612  [ 1280/ 8000]
# loss: 0.344963  [ 2560/ 8000]
# loss: 0.470540  [ 3840/ 8000]
# loss: 0.330818  [ 5120/ 8000]
# loss: 0.203039  [ 6400/ 8000]
# loss: 0.368304  [ 7680/ 8000]
# Test Error:
#  Accuracy: 80.5%, Avg loss: 0.505321
#
# EarlyStopping counter: 1 out of 10
# Epoch 36
# -------------------------------
# loss: 0.360502  [    0/ 8000]
# loss: 0.237658  [ 1280/ 8000]
# loss: 0.564487  [ 2560/ 8000]
# loss: 0.310263  [ 3840/ 8000]
# loss: 0.551410  [ 5120/ 8000]
# loss: 0.573852  [ 6400/ 8000]
# loss: 0.425676  [ 7680/ 8000]
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.402368
#
# EarlyStopping counter: 2 out of 10
# Epoch 37
# -------------------------------
# loss: 0.359745  [    0/ 8000]
# loss: 0.373981  [ 1280/ 8000]
# loss: 0.241915  [ 2560/ 8000]
# loss: 0.253510  [ 3840/ 8000]
# loss: 0.516944  [ 5120/ 8000]
# loss: 0.363565  [ 6400/ 8000]
# loss: 0.481752  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.346621
#
# Validation loss decreased (0.354213 --> 0.346621).  Saving model ...
# Epoch 38
# -------------------------------
# loss: 0.337842  [    0/ 8000]
# loss: 0.337982  [ 1280/ 8000]
# loss: 0.277155  [ 2560/ 8000]
# loss: 0.459698  [ 3840/ 8000]
# loss: 0.333978  [ 5120/ 8000]
# loss: 0.272819  [ 6400/ 8000]
# loss: 0.485279  [ 7680/ 8000]
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.364970
#
# EarlyStopping counter: 1 out of 10
# Epoch 39
# -------------------------------
# loss: 0.190200  [    0/ 8000]
# loss: 0.230724  [ 1280/ 8000]
# loss: 0.352376  [ 2560/ 8000]
# loss: 0.462967  [ 3840/ 8000]
# loss: 0.342567  [ 5120/ 8000]
# loss: 0.508930  [ 6400/ 8000]
# loss: 0.523978  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.351516
#
# EarlyStopping counter: 2 out of 10
# Epoch 40
# -------------------------------
# loss: 0.427300  [    0/ 8000]
# loss: 0.294000  [ 1280/ 8000]
# loss: 0.349029  [ 2560/ 8000]
# loss: 0.432341  [ 3840/ 8000]
# loss: 0.216435  [ 5120/ 8000]
# loss: 0.423391  [ 6400/ 8000]
# loss: 0.426364  [ 7680/ 8000]
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.352577
#
# EarlyStopping counter: 3 out of 10
# Epoch 41
# -------------------------------
# loss: 0.407844  [    0/ 8000]
# loss: 0.584696  [ 1280/ 8000]
# loss: 0.309891  [ 2560/ 8000]
# loss: 0.302677  [ 3840/ 8000]
# loss: 0.311609  [ 5120/ 8000]
# loss: 0.262867  [ 6400/ 8000]
# loss: 0.388766  [ 7680/ 8000]
# Test Error:
#  Accuracy: 85.6%, Avg loss: 0.390803
#
# EarlyStopping counter: 4 out of 10
# Epoch 42
# -------------------------------
# loss: 0.372098  [    0/ 8000]
# loss: 0.311599  [ 1280/ 8000]
# loss: 0.207503  [ 2560/ 8000]
# loss: 0.464645  [ 3840/ 8000]
# loss: 0.406963  [ 5120/ 8000]
# loss: 0.442671  [ 6400/ 8000]
# loss: 0.322490  [ 7680/ 8000]
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.408641
#
# EarlyStopping counter: 5 out of 10
# Epoch 43
# -------------------------------
# loss: 0.453129  [    0/ 8000]
# loss: 0.211062  [ 1280/ 8000]
# loss: 0.338105  [ 2560/ 8000]
# loss: 0.361141  [ 3840/ 8000]
# loss: 0.430420  [ 5120/ 8000]
# loss: 0.278881  [ 6400/ 8000]
# loss: 0.291595  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.350213
#
# EarlyStopping counter: 6 out of 10
# Epoch 44
# -------------------------------
# loss: 0.460656  [    0/ 8000]
# loss: 0.491787  [ 1280/ 8000]
# loss: 0.216187  [ 2560/ 8000]
# loss: 0.306851  [ 3840/ 8000]
# loss: 0.327233  [ 5120/ 8000]
# loss: 0.262260  [ 6400/ 8000]
# loss: 0.447513  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.338426
#
# Validation loss decreased (0.346621 --> 0.338426).  Saving model ...
# Epoch 45
# -------------------------------
# loss: 0.360865  [    0/ 8000]
# loss: 0.333896  [ 1280/ 8000]
# loss: 0.321768  [ 2560/ 8000]
# loss: 0.433426  [ 3840/ 8000]
# loss: 0.192317  [ 5120/ 8000]
# loss: 0.237267  [ 6400/ 8000]
# loss: 0.312157  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.347003
#
# EarlyStopping counter: 1 out of 10
# Epoch 46
# -------------------------------
# loss: 0.237082  [    0/ 8000]
# loss: 0.294451  [ 1280/ 8000]
# loss: 0.212131  [ 2560/ 8000]
# loss: 0.523207  [ 3840/ 8000]
# loss: 0.262076  [ 5120/ 8000]
# loss: 0.442894  [ 6400/ 8000]
# loss: 0.337565  [ 7680/ 8000]
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.372638
#
# EarlyStopping counter: 2 out of 10
# Epoch 47
# -------------------------------
# loss: 0.372902  [    0/ 8000]
# loss: 0.253501  [ 1280/ 8000]
# loss: 0.280441  [ 2560/ 8000]
# loss: 0.202903  [ 3840/ 8000]
# loss: 0.292695  [ 5120/ 8000]
# loss: 0.348645  [ 6400/ 8000]
# loss: 0.374371  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.341417
#
# EarlyStopping counter: 3 out of 10
# Epoch 48
# -------------------------------
# loss: 0.353800  [    0/ 8000]
# loss: 0.189760  [ 1280/ 8000]
# loss: 0.284657  [ 2560/ 8000]
# loss: 0.453188  [ 3840/ 8000]
# loss: 0.178174  [ 5120/ 8000]
# loss: 0.374140  [ 6400/ 8000]
# loss: 0.394308  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.347619
#
# EarlyStopping counter: 4 out of 10
# Epoch 49
# -------------------------------
# loss: 0.407168  [    0/ 8000]
# loss: 0.240754  [ 1280/ 8000]
# loss: 0.372591  [ 2560/ 8000]
# loss: 0.294952  [ 3840/ 8000]
# loss: 0.464660  [ 5120/ 8000]
# loss: 0.355804  [ 6400/ 8000]
# loss: 0.356803  [ 7680/ 8000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.336920
#
# Validation loss decreased (0.338426 --> 0.336920).  Saving model ...
# Epoch 50
# -------------------------------
# loss: 0.272045  [    0/ 8000]
# loss: 0.330752  [ 1280/ 8000]
# loss: 0.390105  [ 2560/ 8000]
# loss: 0.366428  [ 3840/ 8000]
# loss: 0.267405  [ 5120/ 8000]
# loss: 0.270733  [ 6400/ 8000]
# loss: 0.218721  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.335259
#
# Validation loss decreased (0.336920 --> 0.335259).  Saving model ...
# Epoch 51
# -------------------------------
# loss: 0.192053  [    0/ 8000]
# loss: 0.404236  [ 1280/ 8000]
# loss: 0.366146  [ 2560/ 8000]
# loss: 0.404396  [ 3840/ 8000]
# loss: 0.228100  [ 5120/ 8000]
# loss: 0.285361  [ 6400/ 8000]
# loss: 0.238830  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.339498
#
# EarlyStopping counter: 1 out of 10
# Epoch 52
# -------------------------------
# loss: 0.321769  [    0/ 8000]
# loss: 0.353520  [ 1280/ 8000]
# loss: 0.423976  [ 2560/ 8000]
# loss: 0.339060  [ 3840/ 8000]
# loss: 0.236898  [ 5120/ 8000]
# loss: 0.363181  [ 6400/ 8000]
# loss: 0.441650  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.340959
#
# EarlyStopping counter: 2 out of 10
# Epoch 53
# -------------------------------
# loss: 0.314972  [    0/ 8000]
# loss: 0.131632  [ 1280/ 8000]
# loss: 0.350232  [ 2560/ 8000]
# loss: 0.360371  [ 3840/ 8000]
# loss: 0.403812  [ 5120/ 8000]
# loss: 0.332148  [ 6400/ 8000]
# loss: 0.326116  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.344114
#
# EarlyStopping counter: 3 out of 10
# Epoch 54
# -------------------------------
# loss: 0.155973  [    0/ 8000]
# loss: 0.312246  [ 1280/ 8000]
# loss: 0.310041  [ 2560/ 8000]
# loss: 0.256470  [ 3840/ 8000]
# loss: 0.316978  [ 5120/ 8000]
# loss: 0.286122  [ 6400/ 8000]
# loss: 0.398884  [ 7680/ 8000]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.331239
#
# Validation loss decreased (0.335259 --> 0.331239).  Saving model ...
# Epoch 55
# -------------------------------
# loss: 0.405412  [    0/ 8000]
# loss: 0.242887  [ 1280/ 8000]
# loss: 0.492924  [ 2560/ 8000]
# loss: 0.345349  [ 3840/ 8000]
# loss: 0.278122  [ 5120/ 8000]
# loss: 0.715369  [ 6400/ 8000]
# loss: 0.200506  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.336170
#
# EarlyStopping counter: 1 out of 10
# Epoch 56
# -------------------------------
# loss: 0.465362  [    0/ 8000]
# loss: 0.186853  [ 1280/ 8000]
# loss: 0.210143  [ 2560/ 8000]
# loss: 0.384889  [ 3840/ 8000]
# loss: 0.334119  [ 5120/ 8000]
# loss: 0.287139  [ 6400/ 8000]
# loss: 0.315101  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.348504
#
# EarlyStopping counter: 2 out of 10
# Epoch 57
# -------------------------------
# loss: 0.237098  [    0/ 8000]
# loss: 0.251113  [ 1280/ 8000]
# loss: 0.237054  [ 2560/ 8000]
# loss: 0.206249  [ 3840/ 8000]
# loss: 0.285444  [ 5120/ 8000]
# loss: 0.340108  [ 6400/ 8000]
# loss: 0.360405  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.343022
#
# EarlyStopping counter: 3 out of 10
# Epoch 58
# -------------------------------
# loss: 0.258567  [    0/ 8000]
# loss: 0.320386  [ 1280/ 8000]
# loss: 0.233228  [ 2560/ 8000]
# loss: 0.188289  [ 3840/ 8000]
# loss: 0.250668  [ 5120/ 8000]
# loss: 0.261375  [ 6400/ 8000]
# loss: 0.318248  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.343083
#
# EarlyStopping counter: 4 out of 10
# Epoch 59
# -------------------------------
# loss: 0.373724  [    0/ 8000]
# loss: 0.224351  [ 1280/ 8000]
# loss: 0.127593  [ 2560/ 8000]
# loss: 0.299664  [ 3840/ 8000]
# loss: 0.385210  [ 5120/ 8000]
# loss: 0.365157  [ 6400/ 8000]
# loss: 0.298488  [ 7680/ 8000]
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.333531
#
# EarlyStopping counter: 5 out of 10
# Epoch 60
# -------------------------------
# loss: 0.364827  [    0/ 8000]
# loss: 0.329060  [ 1280/ 8000]
# loss: 0.167032  [ 2560/ 8000]
# loss: 0.326133  [ 3840/ 8000]
# loss: 0.574386  [ 5120/ 8000]
# loss: 0.160295  [ 6400/ 8000]
# loss: 0.318998  [ 7680/ 8000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.334179
#
# EarlyStopping counter: 6 out of 10
# Epoch 61
# -------------------------------
# loss: 0.251069  [    0/ 8000]
# loss: 0.168367  [ 1280/ 8000]
# loss: 0.269242  [ 2560/ 8000]
# loss: 0.292359  [ 3840/ 8000]
# loss: 0.317910  [ 5120/ 8000]
# loss: 0.286050  [ 6400/ 8000]
# loss: 0.498239  [ 7680/ 8000]
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.335962
#
# EarlyStopping counter: 7 out of 10
# Epoch 62
# -------------------------------
# loss: 0.328348  [    0/ 8000]
# loss: 0.372068  [ 1280/ 8000]
# loss: 0.166966  [ 2560/ 8000]
# loss: 0.233425  [ 3840/ 8000]
# loss: 0.247062  [ 5120/ 8000]
# loss: 0.376628  [ 6400/ 8000]
# loss: 0.198213  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.340013
#
# EarlyStopping counter: 8 out of 10
# Epoch 63
# -------------------------------
# loss: 0.213383  [    0/ 8000]
# loss: 0.208903  [ 1280/ 8000]
# loss: 0.329798  [ 2560/ 8000]
# loss: 0.272546  [ 3840/ 8000]
# loss: 0.241175  [ 5120/ 8000]
# loss: 0.206334  [ 6400/ 8000]
# loss: 0.264901  [ 7680/ 8000]
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.332183
#
# EarlyStopping counter: 9 out of 10
# Epoch 64
# -------------------------------
# loss: 0.271384  [    0/ 8000]
# loss: 0.426036  [ 1280/ 8000]
# loss: 0.472363  [ 2560/ 8000]
# loss: 0.250813  [ 3840/ 8000]
# loss: 0.281140  [ 5120/ 8000]
# loss: 0.282504  [ 6400/ 8000]
# loss: 0.307083  [ 7680/ 8000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.331287
#
# EarlyStopping counter: 10 out of 10
# Early stopping.
# Done!

# %%
train_loss = model.train_loss_history
valid_loss = model.val_loss_history

# visualize the loss as the network trained
fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(train_loss)+1),train_loss, label='Training Loss')
plt.plot(range(1,len(valid_loss)+1),valid_loss,label='Validation Loss')

# find position of lowest validation loss
minposs = valid_loss.index(min(valid_loss))+1 
plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

plt.xlabel('epochs')
plt.ylabel('loss')
#plt.ylim(0, 0.5) # consistent scale
#plt.xlim(0, len(train_loss)+1) # consistent scale
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
fig.savefig('img/cnn_loss_plot.png', bbox_inches='tight')

# %%
train_acc = model.train_acc_history
valid_acc = model.val_acc_history

# visualize the loss as the network trained
fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(train_acc)+1),train_acc, label='Training accuracy')
plt.plot(range(1,len(valid_acc)+1),valid_acc,label='Validation accuracy')

# find position of lowest validation loss
#minposs = valid_acc.index(min(valid_acc))+1 
plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

plt.xlabel('epochs')
plt.ylabel('loss')
#plt.ylim(0, 0.5) # consistent scale
#plt.xlim(0, len(train_loss)+1) # consistent scale
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
fig.savefig('img/cnn_acc_plot.png', bbox_inches='tight')

# %%
model.test()
# Out:
# Accuracy score for test data
# ------------------------------------------------------------
# Acc: 88.16000000000001 %
#
# Confusion matrix for test data
# ------------------------------------------------------------
# [[843   3  19  26 109]
#  [  1 976   1  16   6]
#  [ 13   3 864  11 109]
#  [ 11   6   5 944  34]
#  [126   0  60  33 781]]

# %% [markdown]
# ### Summary

# %%
summary(model=model, input_size=(1, 1, 28, 28), col_width=20,
                  col_names=['input_size', 'output_size', 'num_params', 'trainable'], row_settings=['var_names'], verbose=0)
# Out:
# ========================================================================================================================
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ========================================================================================================================
# CNN (CNN)                                [1, 1, 28, 28]       [1, 10]              --                   True
# ├─Sequential (nn)                        [1, 1, 28, 28]       [1, 10]              --                   True
# │    └─Conv2d (0)                        [1, 1, 28, 28]       [1, 6, 28, 28]       156                  True
# │    └─BatchNorm2d (1)                   [1, 6, 28, 28]       [1, 6, 28, 28]       12                   True
# │    └─Sigmoid (2)                       [1, 6, 28, 28]       [1, 6, 28, 28]       --                   --
# │    └─AvgPool2d (3)                     [1, 6, 28, 28]       [1, 6, 14, 14]       --                   --
# │    └─Conv2d (4)                        [1, 6, 14, 14]       [1, 16, 10, 10]      2,416                True
# │    └─BatchNorm2d (5)                   [1, 16, 10, 10]      [1, 16, 10, 10]      32                   True
# │    └─Sigmoid (6)                       [1, 16, 10, 10]      [1, 16, 10, 10]      --                   --
# │    └─AvgPool2d (7)                     [1, 16, 10, 10]      [1, 16, 5, 5]        --                   --
# │    └─Flatten (8)                       [1, 16, 5, 5]        [1, 400]             --                   --
# │    └─Dropout (9)                       [1, 400]             [1, 400]             --                   --
# │    └─Linear (10)                       [1, 400]             [1, 120]             48,120               True
# │    └─BatchNorm1d (11)                  [1, 120]             [1, 120]             240                  True
# │    └─Sigmoid (12)                      [1, 120]             [1, 120]             --                   --
# │    └─Dropout (13)                      [1, 120]             [1, 120]             --                   --
# │    └─Linear (14)                       [1, 120]             [1, 84]              10,164               True
# │    └─BatchNorm1d (15)                  [1, 84]              [1, 84]              168                  True
# │    └─Sigmoid (16)                      [1, 84]              [1, 84]              --                   --
# │    └─Dropout (17)                      [1, 84]              [1, 84]              --                   --
# │    └─Linear (18)                       [1, 84]              [1, 10]              850                  True
# ========================================================================================================================
# Total params: 62,158
# Trainable params: 62,158
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.42
# ========================================================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.10
# Params size (MB): 0.25
# Estimated Total Size (MB): 0.36
# ========================================================================================================================
