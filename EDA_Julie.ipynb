# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import pandas as pd
import seaborn as sns

# %%
data_train = np.load('data/fashion_train.npy', mmap_mode='r')
data_test = np.load('data/fashion_test.npy', mmap_mode='r')

# %%
X_train = data_train[:, :-1]
y_train = data_train[:, -1]
X_test = data_test[:, :-1]
y_test = data_test[:, -1]

# %%
print('train',data_train.shape, 'test', data_test.shape)
print('y_train', y_train.shape, 'x_train', X_train.shape)
# Out:
# train (10000, 785) test (5000, 785)
# y_train (10000,) x_train (10000, 784)

# %%
# Plot the distribution of classes
sns.countplot(x=y_train)
plt.title('Class Distribution')
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.show()

# %%
labels_count = [np.sum(y_train == i) for i in range(5)]
labels_count
# Out:
# [2033, 1947, 2001, 2005, 2014]

# %%
img = X_train[0].reshape(28,28)
plt.imshow(img)
